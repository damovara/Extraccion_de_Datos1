# %% [markdown]
# <a href="https://colab.research.google.com/github/damovara/Extraccion_de_Datos1/blob/main/Act1_Extracci%C3%B3n_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Actividad 1 (Extracción de Datos)**
#
#
# *   Daniela Monserrat Vargas Ramírez
# *   A01737287
#
# 1.   Aplicar los 9 filtros descritos en el archivo “1_Extracción_Datos.
#
# 2.   Crear el archivo en Google Colab, respaldarlo en GitHub.

# %%
#Daniela Vargas A01737287
#Se importan las librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo. Directamente lo cargué en el collab en la carpeta y convertirlo en data frame
tabla= pd.read_csv("CountryTable.csv")
tabla
# Out:
#     code          name      continent                     region  \
# 0    ABW         Aruba  North America                  Caribbean
# 1    AFG   Afghanistan           Asia  Southern and Central Asia
# 2    AGO        Angola         Africa             Central Africa
# 3    AIA      Anguilla  North America                  Caribbean
# 4    ALB       Albania         Europe            Southern Europe
# ..   ...           ...            ...                        ...
# 234  YEM         Yemen           Asia                Middle East
# 235  YuG    Yugoslavia         Europe            Southern Europe
# 236  ZAF  South Africa         Africa            Southern Africa
# 237  ZMB        Zambia         Africa             Eastern Africa
# 238  ZWE      Zimbabwe         Africa             Eastern Africa
#
#      surface_area  independence_year  population  life_expectancy       gnp  \
# 0           193.0                NaN      103000             78.4     828.0
# ...

# %%
tabla.head(5)
# Out:
#   code         name      continent                     region  surface_area  \
# 0  ABW        Aruba  North America                  Caribbean         193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia      652090.0
# 2  AGO       Angola         Africa             Central Africa     1246700.0
# 3  AIA     Anguilla  North America                  Caribbean          96.0
# 4  ALB      Albania         Europe            Southern Europe       28748.0
#
#    independence_year  population  life_expectancy     gnp  gnp_old  \
# 0                NaN      103000             78.4   828.0    793.0
# 1             1919.0    22720000             45.9  5976.0      NaN
# 2             1975.0    12878000             38.3  6648.0   7984.0
# 3                NaN        8000             76.1    63.2      NaN
# 4             1912.0     3401200             71.6  3205.0   2500.0
#
#               local_name                               government_form  \
# ...

# %% [markdown]
# _**GENERAR LOS FILTROS BASICOS PARA VARIABLES CUALITATIVAS**_

# %%
#Filtro por objeto FILTRO 1
filtro1=tabla[tabla["name"] == "Mexico"] #Quiero filtrar en la categoría de name el país de México
filtro1#lo imprimo
# Out:
#     code    name      continent           region  surface_area  \
# 135  MEX  Mexico  North America  Central America     1958201.0
#
#      independence_year  population  life_expectancy       gnp   gnp_old  \
# 135             1810.0    98881000             71.5  414972.0  401461.0
#
#     local_name   government_form        head_of_state  capital code2
# 135     Mexico  Federal Republic  Vicente Fox Quesada   2515.0    MX

# %%
#Filtro por filas FILTRO 2
#filtro2= df.iloc[300:302,: ]
filtro2=tabla.iloc[ 135:140, : ]  #filas a partir de 135 a 140 y las columnas son consecutivas
filtro2
# Out:
#     code              name      continent           region  surface_area  \
# 135  MEX            Mexico  North America  Central America     1958201.0
# 136  MHL  Marshall Islands        Oceania       Micronesia         181.0
# 137  MKD         Macedonia         Europe  Southern Europe       25713.0
# 138  MLI              Mali         Africa   Western Africa     1240192.0
# 139  MLT             Malta         Europe  Southern Europe         316.0
#
#      independence_year  population  life_expectancy       gnp   gnp_old  \
# 135             1810.0    98881000             71.5  414972.0  401461.0
# 136             1990.0       64000             65.5      97.0       NaN
# 137             1991.0     2024000             73.8    1694.0    1915.0
# 138             1960.0    11234000             46.7    2642.0    2453.0
# 139             1964.0      380200             77.9    3512.0    3338.0
#
#                  local_name   government_form        head_of_state  capital  \
# ...

# %%
#Filtro por columnas FILTRO 3
filtro3=tabla.iloc[ : , [1,6,10]]  #Las filas son consecutivas y las columnas se filtraron la 1, la 6 y la 10
filtro3
# Out:
#              name  population             local_name
# 0           Aruba      103000                  Aruba
# 1     Afghanistan    22720000  Afganistan/Afqanestan
# 2          Angola    12878000                 Angola
# 3        Anguilla        8000               Anguilla
# 4         Albania     3401200              Shqiperia
# ..            ...         ...                    ...
# 234         Yemen    18112000               Al-Yaman
# 235    Yugoslavia    10640000            Jugoslavija
# 236  South Africa    40377000           South Africa
# 237        Zambia     9169000                 Zambia
# 238      Zimbabwe    11669000               Zimbabwe
#
# [239 rows x 3 columns]

# %%
#Quiero que mi índice sea name
tabla= pd.read_csv("CountryTable.csv", index_col=1)
tabla
# Out:
#              code      continent                     region  surface_area  \
# name
# Aruba         ABW  North America                  Caribbean         193.0
# Afghanistan   AFG           Asia  Southern and Central Asia      652090.0
# Angola        AGO         Africa             Central Africa     1246700.0
# Anguilla      AIA  North America                  Caribbean          96.0
# Albania       ALB         Europe            Southern Europe       28748.0
# ...           ...            ...                        ...           ...
# Yemen         YEM           Asia                Middle East      527968.0
# Yugoslavia    YuG         Europe            Southern Europe      102173.0
# South Africa  ZAF         Africa            Southern Africa     1221037.0
# Zambia        ZMB         Africa             Eastern Africa      752618.0
# Zimbabwe      ZWE         Africa             Eastern Africa      390757.0
#
#               independence_year  population  life_expectancy       gnp  \
# ...

# %%
#Filtro 4 filas vs columnas
#Paso 2: Aplicamos Filtro de filas vs columnas
filtro4=tabla.loc[["Mexico","Yemen","Germany"], ["independence_year"]]
filtro4
#Quiero filtrar los datos de México, Yemen y Alemania pero solo su año de independencia
# Out:
#          independence_year
# name
# Mexico              1810.0
# Yemen               1918.0
# Germany             1955.0

# %%
#Filtro por cabecera FILTRO 6
filtro5=tabla.head(10)
filtro5
#filtar solo las 10 principales lineas de arriba hacia abajo
# Out:
#                      code      continent                     region  \
# name
# Aruba                 ABW  North America                  Caribbean
# Afghanistan           AFG           Asia  Southern and Central Asia
# Angola                AGO         Africa             Central Africa
# Anguilla              AIA  North America                  Caribbean
# Albania               ALB         Europe            Southern Europe
# Andorra               AND         Europe            Southern Europe
# Netherlands Antilles  ANT  North America                  Caribbean
# united Arab Emirates  ARE           Asia                Middle East
# Argentina             ARG  South America              South America
# Armenia               ARM           Asia                Middle East
#
#                       surface_area  independence_year  population  \
# name
# Aruba                        193.0                NaN      103000
# Afghanistan               652090.0             1919.0    22720000
# ...

# %% [markdown]
# _**FILTROS BASICOS PARA VARIABLES CUANTITATIVAS**_

# %%
#Filtro por comparacion FILTRO 6
filtro6=tabla[tabla["population"] > 800000]
filtro6 #Filtrar en la columna population datos mayores a 800000
# Out:
#                      code      continent                     region  \
# name
# Afghanistan           AFG           Asia  Southern and Central Asia
# Angola                AGO         Africa             Central Africa
# Albania               ALB         Europe            Southern Europe
# united Arab Emirates  ARE           Asia                Middle East
# Argentina             ARG  South America              South America
# ...                   ...            ...                        ...
# Yemen                 YEM           Asia                Middle East
# Yugoslavia            YuG         Europe            Southern Europe
# South Africa          ZAF         Africa            Southern Africa
# Zambia                ZMB         Africa             Eastern Africa
# Zimbabwe              ZWE         Africa             Eastern Africa
#
#                       surface_area  independence_year  population  \
# name
# Afghanistan               652090.0             1919.0    22720000
# ...

# %% [markdown]
# _**FILTROS BASICOS CON CONETORES LOGICOS**_

# %%
#Filtro Y (FILTRO 7) filtrar la población mayor a 800000 y la región de Southern Europe
filtro7=tabla[(tabla["population"] > 800000) & (tabla["region"] == "Southern Europe")]
filtro7
# Out:
#                        code continent           region  surface_area  \
# name
# Albania                 ALB    Europe  Southern Europe       28748.0
# Bosnia and Herzegovina  BIH    Europe  Southern Europe       51197.0
# Spain                   ESP    Europe  Southern Europe      505992.0
# Greece                  GRC    Europe  Southern Europe      131626.0
# Croatia                 HRV    Europe  Southern Europe       56538.0
# Italy                   ITA    Europe  Southern Europe      301316.0
# Macedonia               MKD    Europe  Southern Europe       25713.0
# Portugal                PRT    Europe  Southern Europe       91982.0
# Slovenia                SVN    Europe  Southern Europe       20256.0
# Yugoslavia              YuG    Europe  Southern Europe      102173.0
#
#                         independence_year  population  life_expectancy  \
# name
# Albania                            1912.0     3401200             71.6
# ...

# %%
#Filtro o (FILTRO 8) filtrar la población mayor a 800000 ó la región de Southern Europe
filtro8=tabla[(tabla["population"] > 800000) | (tabla["region"] == "Southern Europe")]
filtro8
# Out:
#                      code continent                     region  surface_area  \
# name
# Afghanistan           AFG      Asia  Southern and Central Asia      652090.0
# Angola                AGO    Africa             Central Africa     1246700.0
# Albania               ALB    Europe            Southern Europe       28748.0
# Andorra               AND    Europe            Southern Europe         468.0
# united Arab Emirates  ARE      Asia                Middle East       83600.0
# ...                   ...       ...                        ...           ...
# Yemen                 YEM      Asia                Middle East      527968.0
# Yugoslavia            YuG    Europe            Southern Europe      102173.0
# South Africa          ZAF    Africa            Southern Africa     1221037.0
# Zambia                ZMB    Africa             Eastern Africa      752618.0
# Zimbabwe              ZWE    Africa             Eastern Africa      390757.0
#
# ...

# %%
#Filtro not (FILTRO 9) no filtrar la población mayor a 800000 y diferente a la región de Southern Europe
filtro9=tabla[~(tabla["population"] >= 800000) & ~ (tabla["region"] == "Southern Europe")]
filtro9
# Out:
#                         code      continent      region  surface_area  \
# name
# Aruba                    ABW  North America   Caribbean         193.0
# Anguilla                 AIA  North America   Caribbean          96.0
# Netherlands Antilles     ANT  North America   Caribbean         800.0
# American Samoa           ASM        Oceania   Polynesia         199.0
# Antarctica               ATA     Antarctica  Antarctica    13120000.0
# ...                      ...            ...         ...           ...
# Virgin Islands, British  VGB  North America   Caribbean         151.0
# Virgin Islands, u.S.     VIR  North America   Caribbean         347.0
# Vanuatu                  VuT        Oceania   Melanesia       12189.0
# Wallis and Futuna        WLF        Oceania   Polynesia         200.0
# Samoa                    WSM        Oceania   Polynesia        2831.0
#
#                          independence_year  population  life_expectancy  \
# name
# ...

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("Filtro 9.csv")

# %%
#Convertir archivo filtrado a CSV
filtro8.to_csv("Filtro 8.csv")

# %%
#Convertir archivo filtrado a CSV
filtro7.to_csv("Filtro 7.csv")

# %%
#Convertir archivo filtrado a CSV
filtro6.to_csv("Filtro 6.csv")

# %%
#Convertir archivo filtrado a CSV
filtro5.to_csv("Filtro 5.csv")

# %%
#Convertir archivo filtrado a CSV
filtro4.to_csv("Filtro 4.csv")

# %%
#Convertir archivo filtrado a CSV
filtro3.to_csv("Filtro 3.csv")

# %%
#Convertir archivo filtrado a CSV
filtro2.to_csv("Filtro 2.csv")

# %%
#Convertir archivo filtrado a CSV
filtro1.to_csv("Filtro 1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files

files.download("Filtro 1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files

files.download("Filtro 2.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files

files.download("Filtro 3.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files

files.download("Filtro 4.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files

files.download("Filtro 5.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files

files.download("Filtro 6.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files

files.download("Filtro 7.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files

files.download("Filtro 8.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files

files.download("Filtro 9.csv")
